# %%
import numpy as np
import os
import keras
from keras.layers import Dense,GlobalAveragePooling2D
from keras.applications.resnet50 import ResNet50
from keras.applications import VGG16
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.optimizers import Adam

from UnetModel import *

# %matplotlib inline


#Load pre-trained model
UnetModel.img_rows = 224
UnetModel.img_cols = 224

UnetModel.batch_size = 6
UnetModel.batch_norm = False
UnetModel.layer_norm = True

input_shape = (UnetModel.img_rows,UnetModel.img_cols,3)
#base_model=ResNet50(weights='imagenet',include_top=False, input_shape = input_shape) #imports the resnet model and discards the last 1000 neuron layer.
base_model=ResNet50(weights='imagenet',include_top=False, input_shape = input_shape) #imports the resnet model and discards the last 1000 neuron layer.

# %%
for layer in base_model.layers:
    layer.trainable = True
    
x = base_model.output

bottom  = double_block(x, 1024, prefix='bottom')

# 14 x 14 block5
left_block5 = base_model.get_layer('activation_40').output
right_conv5 = up_sampling_block(bottom, left_block5, 512, 'right_conv5')

# 28 x 28 block4
left_block4 = base_model.get_layer('activation_22').output
right_conv4 = up_sampling_block(right_conv5, left_block4, 256, 'right_conv4')

# 56 x 56 block3
left_block3 = base_model.get_layer('activation_10').output
right_conv3 = up_sampling_block(right_conv4, left_block3, 128, 'right_conv3')

# 112 x 112 block2
left_block2 = base_model.get_layer('activation_1').output
right_conv2 = up_sampling_block(right_conv3, left_block2, 64, 'right_conv2')

#Resnet doesn't have 224 x 224 layer conv, use first conv layer in VGG16 instead
vgg = VGG16(input_shape=input_shape, input_tensor=base_model.input, include_top=False)
for l in vgg.layers:
    l.trainable = True
vgg_first_conv = vgg.get_layer("block1_conv2").output
right_conv1 = up_sampling_block(right_conv2, vgg_first_conv, 32, 'right_conv1')
right_dropout1 = SpatialDropout2D(0.2)(right_conv1)

#Sigmoid
output = Conv2D(1, (1, 1), activation='sigmoid')(right_dropout1)
model = Model(inputs=base_model.input, outputs=output)

model.compile(optimizer=Adam(lr=1e-4, decay = 0.1), loss=jaccard_coef_loss, metrics=[jaccard_coef])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b022445077eb> in <module>
#       4 x = base_model.output
#       5
# ----> 6 bottom  = double_block(x, 1024, prefix='bottom')
#       7
#       8 # 14 x 14 block5
#
# c:\notebooks\MelanomaSegmentation\UnetModel.py in double_block(prevlayer, filters, prefix, strides)
#      97
#      98 def double_block(prevlayer, filters, prefix, strides=(1, 1)):
# ---> 99     layer1 = conv_block(prevlayer, filters, prefix+"1", strides)
#     100     layer2 = conv_block(layer1   , filters, prefix+"2", strides)
#     101     return layer2
#
# c:\notebooks\MelanomaSegmentation\UnetModel.py in conv_block(prevlayer, filters, prefix, strides)
#      91     if batch_norm:
#      92         conv = BatchNormalization(name=prefix + "_bn")(conv)
# ---> 93     if layer_norm:
#      94         conv = LayerNormalization()(conv)
#      95     conv = LeakyReLU(alpha=0.001, name=prefix + "_activation")(conv)
#
# NameError: name 'layer_norm' is not defined

# %%
myGene = trainGenerator(batch_size,'data/train','images','masks',data_val_gen_args, target_size= (UnetModel.img_rows,UnetModel.img_rows))
myValGene = validationGenerator(batch_size,'data/val','images','masks',data_val_gen_args, target_size= (UnetModel.img_rows,UnetModel.img_rows))

iterations = 100
# Train head
history = model.fit_generator(
    myGene,
    steps_per_epoch = 300, 
    epochs=iterations,
    callbacks=[model_checkpoint],
    validation_data=myValGene,
    validation_steps=100)

model.save(os.path.join(output_dir, 'transfer_learning_iter_100'.format(iterations)))
# Out:
# Epoch 1/100
# Found 519 images belonging to 1 classes.
# Found 1555 images belonging to 1 classes.
# Found 519 images belonging to 1 classes.
# Found 1555 images belonging to 1 classes.
# 300/300 [==============================] - 540s 2s/step - loss: -0.3673 - jaccard_coef: 0.3673 - val_loss: -0.4229 - val_jaccard_coef: 0.4229
#
# Epoch 00001: val_jaccard_coef improved from 0.33909 to 0.42291, saving model to unet/20190524/unet_lesion_20190524_001-0.42291.hdf5
# Epoch 2/100
# 300/300 [==============================] - 506s 2s/step - loss: -0.4132 - jaccard_coef: 0.4132 - val_loss: -0.4427 - val_jaccard_coef: 0.4427
#
# Epoch 00002: val_jaccard_coef improved from 0.42291 to 0.44269, saving model to unet/20190524/unet_lesion_20190524_002-0.44269.hdf5
# Epoch 3/100
# 300/300 [==============================] - 518s 2s/step - loss: -0.4430 - jaccard_coef: 0.4430 - val_loss: -0.4566 - val_jaccard_coef: 0.4566
#
# Epoch 00003: val_jaccard_coef improved from 0.44269 to 0.45664, saving model to unet/20190524/unet_lesion_20190524_003-0.45664.hdf5
# Epoch 4/100
# 300/300 [==============================] - 506s 2s/step - loss: -0.4497 - jaccard_coef: 0.4497 - val_loss: -0.4721 - val_jaccard_coef: 0.4721
#
# Epoch 00004: val_jaccard_coef improved from 0.45664 to 0.47214, saving model to unet/20190524/unet_lesion_20190524_004-0.47214.hdf5
# Epoch 5/100
# 300/300 [==============================] - 523s 2s/step - loss: -0.4638 - jaccard_coef: 0.4638 - val_loss: -0.4864 - val_jaccard_coef: 0.4864
#
# Epoch 00005: val_jaccard_coef improved from 0.47214 to 0.48643, saving model to unet/20190524/unet_lesion_20190524_005-0.48643.hdf5
# Epoch 6/100
# 300/300 [==============================] - 509s 2s/step - loss: -0.4606 - jaccard_coef: 0.4606 - val_loss: -0.4814 - val_jaccard_coef: 0.4814
#
# Epoch 00006: val_jaccard_coef did not improve from 0.48643
# Epoch 7/100
# 300/300 [==============================] - 511s 2s/step - loss: -0.4777 - jaccard_coef: 0.4777 - val_loss: -0.4849 - val_jaccard_coef: 0.4849
#
# Epoch 00007: val_jaccard_coef did not improve from 0.48643
# Epoch 8/100
# 300/300 [==============================] - 508s 2s/step - loss: -0.4707 - jaccard_coef: 0.4707 - val_loss: -0.4849 - val_jaccard_coef: 0.4849
#
# Epoch 00008: val_jaccard_coef did not improve from 0.48643
# Epoch 9/100
# 300/300 [==============================] - 501s 2s/step - loss: -0.4917 - jaccard_coef: 0.4917 - val_loss: -0.5003 - val_jaccard_coef: 0.5003
#
# Epoch 00009: val_jaccard_coef improved from 0.48643 to 0.50033, saving model to unet/20190524/unet_lesion_20190524_009-0.50033.hdf5
# Epoch 10/100
# 300/300 [==============================] - 513s 2s/step - loss: -0.4757 - jaccard_coef: 0.4757 - val_loss: -0.4765 - val_jaccard_coef: 0.4765
#
# Epoch 00010: val_jaccard_coef did not improve from 0.50033
# Epoch 11/100
# 300/300 [==============================] - 506s 2s/step - loss: -0.4948 - jaccard_coef: 0.4948 - val_loss: -0.4997 - val_jaccard_coef: 0.4997
#
# Epoch 00011: val_jaccard_coef did not improve from 0.50033
# Epoch 12/100
# 300/300 [==============================] - 515s 2s/step - loss: -0.4861 - jaccard_coef: 0.4861 - val_loss: -0.4973 - val_jaccard_coef: 0.4973
#
# Epoch 00012: val_jaccard_coef did not improve from 0.50033
# Epoch 13/100
# 300/300 [==============================] - 506s 2s/step - loss: -0.4891 - jaccard_coef: 0.4891 - val_loss: -0.5024 - val_jaccard_coef: 0.5024
#
# Epoch 00013: val_jaccard_coef improved from 0.50033 to 0.50237, saving model to unet/20190524/unet_lesion_20190524_013-0.50237.hdf5
# Epoch 14/100
# 300/300 [==============================] - 503s 2s/step - loss: -0.4888 - jaccard_coef: 0.4888 - val_loss: -0.5059 - val_jaccard_coef: 0.5059
#
# Epoch 00014: val_jaccard_coef improved from 0.50237 to 0.50589, saving model to unet/20190524/unet_lesion_20190524_014-0.50589.hdf5
# Epoch 15/100
# 300/300 [==============================] - 522s 2s/step - loss: -0.4954 - jaccard_coef: 0.4954 - val_loss: -0.4952 - val_jaccard_coef: 0.4952
#
# Epoch 00015: val_jaccard_coef did not improve from 0.50589
# Epoch 16/100
# 300/300 [==============================] - 512s 2s/step - loss: -0.5017 - jaccard_coef: 0.5017 - val_loss: -0.4998 - val_jaccard_coef: 0.4998
#
# Epoch 00016: val_jaccard_coef did not improve from 0.50589
# Epoch 17/100
# 300/300 [==============================] - 517s 2s/step - loss: -0.4914 - jaccard_coef: 0.4914 - val_loss: -0.5055 - val_jaccard_coef: 0.5055
#
# Epoch 00017: val_jaccard_coef did not improve from 0.50589
# Epoch 18/100
# 300/300 [==============================] - 499s 2s/step - loss: -0.5068 - jaccard_coef: 0.5068 - val_loss: -0.5011 - val_jaccard_coef: 0.5011
#
# Epoch 00018: val_jaccard_coef did not improve from 0.50589
# Epoch 19/100
# 300/300 [==============================] - 515s 2s/step - loss: -0.5035 - jaccard_coef: 0.5035 - val_loss: -0.5191 - val_jaccard_coef: 0.5191
#
# Epoch 00019: val_jaccard_coef improved from 0.50589 to 0.51908, saving model to unet/20190524/unet_lesion_20190524_019-0.51908.hdf5
# Epoch 20/100
# 300/300 [==============================] - 510s 2s/step - loss: -0.5081 - jaccard_coef: 0.5081 - val_loss: -0.5054 - val_jaccard_coef: 0.5054
#
# Epoch 00020: val_jaccard_coef did not improve from 0.51908
# Epoch 21/100
# 300/300 [==============================] - 501s 2s/step - loss: -0.5046 - jaccard_coef: 0.5046 - val_loss: -0.5143 - val_jaccard_coef: 0.5143
#
# Epoch 00021: val_jaccard_coef did not improve from 0.51908
# Epoch 22/100
# 300/300 [==============================] - 513s 2s/step - loss: -0.5031 - jaccard_coef: 0.5031 - val_loss: -0.5042 - val_jaccard_coef: 0.5042
#
# Epoch 00022: val_jaccard_coef did not improve from 0.51908
# Epoch 23/100
# 300/300 [==============================] - 518s 2s/step - loss: -0.5048 - jaccard_coef: 0.5048 - val_loss: -0.5101 - val_jaccard_coef: 0.5101
#
# Epoch 00023: val_jaccard_coef did not improve from 0.51908
# Epoch 24/100
# 300/300 [==============================] - 503s 2s/step - loss: -0.5123 - jaccard_coef: 0.5123 - val_loss: -0.5123 - val_jaccard_coef: 0.5123
#
# Epoch 00024: val_jaccard_coef did not improve from 0.51908
# Epoch 25/100
# 300/300 [==============================] - 511s 2s/step - loss: -0.5042 - jaccard_coef: 0.5042 - val_loss: -0.5187 - val_jaccard_coef: 0.5187
#
# Epoch 00025: val_jaccard_coef did not improve from 0.51908
# Epoch 26/100
# 300/300 [==============================] - 511s 2s/step - loss: -0.5097 - jaccard_coef: 0.5097 - val_loss: -0.5090 - val_jaccard_coef: 0.5090
#
# Epoch 00026: val_jaccard_coef did not improve from 0.51908
# Epoch 27/100
# 300/300 [==============================] - 509s 2s/step - loss: -0.5061 - jaccard_coef: 0.5061 - val_loss: -0.5080 - val_jaccard_coef: 0.5080
#
# Epoch 00027: val_jaccard_coef did not improve from 0.51908
# Epoch 28/100
# 300/300 [==============================] - 510s 2s/step - loss: -0.5207 - jaccard_coef: 0.5207 - val_loss: -0.5131 - val_jaccard_coef: 0.5131
#
# Epoch 00028: val_jaccard_coef did not improve from 0.51908
# Epoch 29/100
# 300/300 [==============================] - 518s 2s/step - loss: -0.5050 - jaccard_coef: 0.5050 - val_loss: -0.5152 - val_jaccard_coef: 0.5152
#
# Epoch 00029: val_jaccard_coef did not improve from 0.51908
# Epoch 30/100
# 300/300 [==============================] - 510s 2s/step - loss: -0.5234 - jaccard_coef: 0.5234 - val_loss: -0.5211 - val_jaccard_coef: 0.5211
#
# Epoch 00030: val_jaccard_coef improved from 0.51908 to 0.52114, saving model to unet/20190524/unet_lesion_20190524_030-0.52114.hdf5
# Epoch 31/100
# 300/300 [==============================] - 507s 2s/step - loss: -0.5178 - jaccard_coef: 0.5178 - val_loss: -0.5296 - val_jaccard_coef: 0.5296
#
# Epoch 00031: val_jaccard_coef improved from 0.52114 to 0.52962, saving model to unet/20190524/unet_lesion_20190524_031-0.52962.hdf5
# Epoch 32/100
# 300/300 [==============================] - 514s 2s/step - loss: -0.5187 - jaccard_coef: 0.5187 - val_loss: -0.5105 - val_jaccard_coef: 0.5105
#
# Epoch 00032: val_jaccard_coef did not improve from 0.52962
# Epoch 33/100
# 300/300 [==============================] - 502s 2s/step - loss: -0.5138 - jaccard_coef: 0.5138 - val_loss: -0.5068 - val_jaccard_coef: 0.5068
#
# Epoch 00033: val_jaccard_coef did not improve from 0.52962
# Epoch 34/100
# 300/300 [==============================] - 513s 2s/step - loss: -0.5204 - jaccard_coef: 0.5204 - val_loss: -0.5219 - val_jaccard_coef: 0.5219
# Epoch 00034: val_jaccard_coef did not improve from 0.52962
# Epoch 35/100
# 300/300 [==============================] - 513s 2s/step - loss: -0.5199 - jaccard_coef: 0.5199 - val_loss: -0.5231 - val_jaccard_coef: 0.5231
#
# Epoch 00035: val_jaccard_coef did not improve from 0.52962
# Epoch 36/100
# 300/300 [==============================] - 506s 2s/step - loss: -0.5216 - jaccard_coef: 0.5216 - val_loss: -0.5151 - val_jaccard_coef: 0.5151
#
# Epoch 00036: val_jaccard_coef did not improve from 0.52962
# Epoch 37/100
# 300/300 [==============================] - 518s 2s/step - loss: -0.5202 - jaccard_coef: 0.5202 - val_loss: -0.5237 - val_jaccard_coef: 0.5237
#
# Epoch 00037: val_jaccard_coef did not improve from 0.52962
# Epoch 38/100
# 300/300 [==============================] - 502s 2s/step - loss: -0.5175 - jaccard_coef: 0.5175 - val_loss: -0.5295 - val_jaccard_coef: 0.5295
#
# Epoch 00038: val_jaccard_coef did not improve from 0.52962
# Epoch 39/100
# 300/300 [==============================] - 507s 2s/step - loss: -0.5188 - jaccard_coef: 0.5188 - val_loss: -0.5220 - val_jaccard_coef: 0.5220
#
# Epoch 00039: val_jaccard_coef did not improve from 0.52962
# Epoch 40/100
# 300/300 [==============================] - 511s 2s/step - loss: -0.5271 - jaccard_coef: 0.5271 - val_loss: -0.5150 - val_jaccard_coef: 0.5150
#
# Epoch 00040: val_jaccard_coef did not improve from 0.52962
# Epoch 41/100
# 300/300 [==============================] - 510s 2s/step - loss: -0.5197 - jaccard_coef: 0.5197 - val_loss: -0.5244 - val_jaccard_coef: 0.5244
#
# Epoch 00041: val_jaccard_coef did not improve from 0.52962
# Epoch 42/100
# 300/300 [==============================] - 522s 2s/step - loss: -0.5234 - jaccard_coef: 0.5234 - val_loss: -0.5153 - val_jaccard_coef: 0.5153
#
# Epoch 00042: val_jaccard_coef did not improve from 0.52962
# Epoch 43/100
# 300/300 [==============================] - 494s 2s/step - loss: -0.5267 - jaccard_coef: 0.5267 - val_loss: -0.5280 - val_jaccard_coef: 0.5280
#
# Epoch 00043: val_jaccard_coef did not improve from 0.52962
# Epoch 44/100
# 300/300 [==============================] - 520s 2s/step - loss: -0.5261 - jaccard_coef: 0.5261 - val_loss: -0.5158 - val_jaccard_coef: 0.5158
#
# Epoch 00044: val_jaccard_coef did not improve from 0.52962
# Epoch 45/100
# 300/300 [==============================] - 507s 2s/step - loss: -0.5159 - jaccard_coef: 0.5159 - val_loss: -0.5252 - val_jaccard_coef: 0.5252
#
# Epoch 00045: val_jaccard_coef did not improve from 0.52962
# Epoch 46/100
# 300/300 [==============================] - 508s 2s/step - loss: -0.5316 - jaccard_coef: 0.5316 - val_loss: -0.5275 - val_jaccard_coef: 0.5275
#
# Epoch 00046: val_jaccard_coef did not improve from 0.52962
# Epoch 47/100
# 300/300 [==============================] - 505s 2s/step - loss: -0.5232 - jaccard_coef: 0.5232 - val_loss: -0.5150 - val_jaccard_coef: 0.5150
#
# Epoch 00047: val_jaccard_coef did not improve from 0.52962
# Epoch 48/100
# 300/300 [==============================] - 510s 2s/step - loss: -0.5324 - jaccard_coef: 0.5324 - val_loss: -0.5233 - val_jaccard_coef: 0.5233
#
# Epoch 00048: val_jaccard_coef did not improve from 0.52962
# Epoch 49/100
# 300/300 [==============================] - 512s 2s/step - loss: -0.5199 - jaccard_coef: 0.5199 - val_loss: -0.5313 - val_jaccard_coef: 0.5313
#
# Epoch 00049: val_jaccard_coef improved from 0.52962 to 0.53133, saving model to unet/20190524/unet_lesion_20190524_049-0.53133.hdf5
# Epoch 50/100
# 300/300 [==============================] - 517s 2s/step - loss: -0.5310 - jaccard_coef: 0.5310 - val_loss: -0.5306 - val_jaccard_coef: 0.5306
#
# Epoch 00050: val_jaccard_coef did not improve from 0.53133
# Epoch 51/100
# 300/300 [==============================] - 517s 2s/step - loss: -0.5281 - jaccard_coef: 0.5281 - val_loss: -0.5265 - val_jaccard_coef: 0.5265
#
# Epoch 00051: val_jaccard_coef did not improve from 0.53133
# Epoch 52/100
# 300/300 [==============================] - 512s 2s/step - loss: -0.5229 - jaccard_coef: 0.5229 - val_loss: -0.5217 - val_jaccard_coef: 0.5217
#
# Epoch 00052: val_jaccard_coef did not improve from 0.53133
# Epoch 53/100
# 300/300 [==============================] - 507s 2s/step - loss: -0.5293 - jaccard_coef: 0.5293 - val_loss: -0.5208 - val_jaccard_coef: 0.5208
#
# Epoch 00053: val_jaccard_coef did not improve from 0.53133
# Epoch 54/100
# 300/300 [==============================] - 539s 2s/step - loss: -0.5305 - jaccard_coef: 0.5305 - val_loss: -0.5386 - val_jaccard_coef: 0.5386
#
# Epoch 00054: val_jaccard_coef improved from 0.53133 to 0.53858, saving model to unet/20190524/unet_lesion_20190524_054-0.53858.hdf5
# Epoch 55/100
# 300/300 [==============================] - 502s 2s/step - loss: -0.5165 - jaccard_coef: 0.5165 - val_loss: -0.5216 - val_jaccard_coef: 0.5216
#
# Epoch 00055: val_jaccard_coef did not improve from 0.53858
# Epoch 56/100
# 300/300 [==============================] - 510s 2s/step - loss: -0.5325 - jaccard_coef: 0.5325 - val_loss: -0.5301 - val_jaccard_coef: 0.5301
#
# Epoch 00056: val_jaccard_coef did not improve from 0.53858
# Epoch 57/100
# 300/300 [==============================] - 521s 2s/step - loss: -0.5305 - jaccard_coef: 0.5305 - val_loss: -0.5336 - val_jaccard_coef: 0.5336
#
# Epoch 00057: val_jaccard_coef did not improve from 0.53858
# Epoch 58/100
# 300/300 [==============================] - 506s 2s/step - loss: -0.5350 - jaccard_coef: 0.5350 - val_loss: -0.5301 - val_jaccard_coef: 0.5301
#
# Epoch 00058: val_jaccard_coef did not improve from 0.53858
# Epoch 59/100
# 300/300 [==============================] - 510s 2s/step - loss: -0.5262 - jaccard_coef: 0.5262 - val_loss: -0.5258 - val_jaccard_coef: 0.5258
#
# Epoch 00059: val_jaccard_coef did not improve from 0.53858
# Epoch 60/100
# 300/300 [==============================] - 515s 2s/step - loss: -0.5353 - jaccard_coef: 0.5353 - val_loss: -0.5262 - val_jaccard_coef: 0.5262
#
# Epoch 00060: val_jaccard_coef did not improve from 0.53858
# Epoch 61/100
# 300/300 [==============================] - 529s 2s/step - loss: -0.5274 - jaccard_coef: 0.5274 - val_loss: -0.5296 - val_jaccard_coef: 0.5296
#
# Epoch 00061: val_jaccard_coef did not improve from 0.53858
# Epoch 62/100
# 300/300 [==============================] - 532s 2s/step - loss: -0.5248 - jaccard_coef: 0.5248 - val_loss: -0.5281 - val_jaccard_coef: 0.5281
#
# Epoch 00062: val_jaccard_coef did not improve from 0.53858
# Epoch 63/100
# 300/300 [==============================] - 523s 2s/step - loss: -0.5418 - jaccard_coef: 0.5418 - val_loss: -0.5300 - val_jaccard_coef: 0.5300
#
# Epoch 00063: val_jaccard_coef did not improve from 0.53858
# Epoch 64/100
# 300/300 [==============================] - 517s 2s/step - loss: -0.5216 - jaccard_coef: 0.5216 - val_loss: -0.5359 - val_jaccard_coef: 0.5359
#
# Epoch 00064: val_jaccard_coef did not improve from 0.53858
# Epoch 65/100
# 300/300 [==============================] - 512s 2s/step - loss: -0.5377 - jaccard_coef: 0.5377 - val_loss: -0.5266 - val_jaccard_coef: 0.5266
#
# Epoch 00065: val_jaccard_coef did not improve from 0.53858
# Epoch 66/100
# 300/300 [==============================] - 524s 2s/step - loss: -0.5348 - jaccard_coef: 0.5348 - val_loss: -0.5347 - val_jaccard_coef: 0.5347
#
# Epoch 00066: val_jaccard_coef did not improve from 0.53858
# Epoch 67/100
# 300/300 [==============================] - 517s 2s/step - loss: -0.5265 - jaccard_coef: 0.5265 - val_loss: -0.5317 - val_jaccard_coef: 0.5317
#
# Epoch 00067: val_jaccard_coef did not improve from 0.53858
# Epoch 68/100
# 300/300 [==============================] - 512s 2s/step - loss: -0.5356 - jaccard_coef: 0.5356 - val_loss: -0.5191 - val_jaccard_coef: 0.5191
#
# Epoch 00068: val_jaccard_coef did not improve from 0.53858
# Epoch 69/100
# 300/300 [==============================] - 525s 2s/step - loss: -0.5290 - jaccard_coef: 0.5290 - val_loss: -0.5396 - val_jaccard_coef: 0.5396
#
# Epoch 00069: val_jaccard_coef improved from 0.53858 to 0.53964, saving model to unet/20190524/unet_lesion_20190524_069-0.53964.hdf5
# Epoch 70/100
# 300/300 [==============================] - 525s 2s/step - loss: -0.5380 - jaccard_coef: 0.5380 - val_loss: -0.5288 - val_jaccard_coef: 0.5288
#
# Epoch 00070: val_jaccard_coef did not improve from 0.53964
# Epoch 71/100
# 300/300 [==============================] - 529s 2s/step - loss: -0.5374 - jaccard_coef: 0.5374 - val_loss: -0.5439 - val_jaccard_coef: 0.5439
#
# Epoch 00071: val_jaccard_coef improved from 0.53964 to 0.54386, saving model to unet/20190524/unet_lesion_20190524_071-0.54386.hdf5
# Epoch 72/100
# 300/300 [==============================] - 516s 2s/step - loss: -0.5399 - jaccard_coef: 0.5399 - val_loss: -0.5164 - val_jaccard_coef: 0.5164
#
# Epoch 00072: val_jaccard_coef did not improve from 0.54386
# Epoch 73/100
# 300/300 [==============================] - 526s 2s/step - loss: -0.5287 - jaccard_coef: 0.5287 - val_loss: -0.5321 - val_jaccard_coef: 0.5321
#
# Epoch 00073: val_jaccard_coef did not improve from 0.54386
# Epoch 74/100
# 300/300 [==============================] - 506s 2s/step - loss: -0.5342 - jaccard_coef: 0.5342 - val_loss: -0.5284 - val_jaccard_coef: 0.5284
#
# Epoch 00074: val_jaccard_coef did not improve from 0.54386
# Epoch 75/100
# 300/300 [==============================] - 520s 2s/step - loss: -0.5373 - jaccard_coef: 0.5373 - val_loss: -0.5377 - val_jaccard_coef: 0.5377
#
# Epoch 00075: val_jaccard_coef did not improve from 0.54386
# Epoch 76/100
# 300/300 [==============================] - 515s 2s/step - loss: -0.5331 - jaccard_coef: 0.5331 - val_loss: -0.5374 - val_jaccard_coef: 0.5374
#
# Epoch 00076: val_jaccard_coef did not improve from 0.54386
# Epoch 77/100
# 300/300 [==============================] - 519s 2s/step - loss: -0.5274 - jaccard_coef: 0.5274 - val_loss: -0.5316 - val_jaccard_coef: 0.5316
#
# Epoch 00077: val_jaccard_coef did not improve from 0.54386
# Epoch 78/100
# 300/300 [==============================] - 514s 2s/step - loss: -0.5429 - jaccard_coef: 0.5429 - val_loss: -0.5327 - val_jaccard_coef: 0.5327
#
# Epoch 00078: val_jaccard_coef did not improve from 0.54386
# Epoch 79/100
# 300/300 [==============================] - 517s 2s/step - loss: -0.5420 - jaccard_coef: 0.5420 - val_loss: -0.5372 - val_jaccard_coef: 0.5372
#
# Epoch 00079: val_jaccard_coef did not improve from 0.54386
# Epoch 80/100
# 300/300 [==============================] - 510s 2s/step - loss: -0.5303 - jaccard_coef: 0.5303 - val_loss: -0.5222 - val_jaccard_coef: 0.5222
#
# Epoch 00080: val_jaccard_coef did not improve from 0.54386
# Epoch 81/100
# 300/300 [==============================] - 517s 2s/step - loss: -0.5350 - jaccard_coef: 0.5350 - val_loss: -0.5478 - val_jaccard_coef: 0.5478
#
# Epoch 00081: val_jaccard_coef improved from 0.54386 to 0.54776, saving model to unet/20190524/unet_lesion_20190524_081-0.54776.hdf5
# Epoch 82/100
# 300/300 [==============================] - 524s 2s/step - loss: -0.5322 - jaccard_coef: 0.5322 - val_loss: -0.5269 - val_jaccard_coef: 0.5269
#
# Epoch 00082: val_jaccard_coef did not improve from 0.54776
# Epoch 83/100
# 300/300 [==============================] - 511s 2s/step - loss: -0.5398 - jaccard_coef: 0.5398 - val_loss: -0.5401 - val_jaccard_coef: 0.5401
#
# Epoch 00083: val_jaccard_coef did not improve from 0.54776
# Epoch 84/100
# 300/300 [==============================] - 508s 2s/step - loss: -0.5313 - jaccard_coef: 0.5313 - val_loss: -0.5446 - val_jaccard_coef: 0.5446
#
# Epoch 00084: val_jaccard_coef did not improve from 0.54776
# Epoch 85/100
# 300/300 [==============================] - 511s 2s/step - loss: -0.5430 - jaccard_coef: 0.5430 - val_loss: -0.5311 - val_jaccard_coef: 0.5311
#
# Epoch 00085: val_jaccard_coef did not improve from 0.54776
# Epoch 86/100
# 300/300 [==============================] - 516s 2s/step - loss: -0.5433 - jaccard_coef: 0.5433 - val_loss: -0.5348 - val_jaccard_coef: 0.5348
#
# Epoch 00086: val_jaccard_coef did not improve from 0.54776
# Epoch 87/100
# 300/300 [==============================] - 508s 2s/step - loss: -0.5359 - jaccard_coef: 0.5359 - val_loss: -0.5299 - val_jaccard_coef: 0.5299
#
# Epoch 00087: val_jaccard_coef did not improve from 0.54776
# Epoch 88/100
# 300/300 [==============================] - 511s 2s/step - loss: -0.5447 - jaccard_coef: 0.5447 - val_loss: -0.5296 - val_jaccard_coef: 0.5296
#
# Epoch 00088: val_jaccard_coef did not improve from 0.54776
# Epoch 89/100
# 300/300 [==============================] - 517s 2s/step - loss: -0.5350 - jaccard_coef: 0.5350 - val_loss: -0.5318 - val_jaccard_coef: 0.5318
#
# Epoch 00089: val_jaccard_coef did not improve from 0.54776
# Epoch 90/100
# 300/300 [==============================] - 517s 2s/step - loss: -0.5414 - jaccard_coef: 0.5414 - val_loss: -0.5467 - val_jaccard_coef: 0.5467
#
# Epoch 00090: val_jaccard_coef did not improve from 0.54776
# Epoch 91/100
# 300/300 [==============================] - 511s 2s/step - loss: -0.5392 - jaccard_coef: 0.5392 - val_loss: -0.5389 - val_jaccard_coef: 0.5389
#
# Epoch 00091: val_jaccard_coef did not improve from 0.54776
# Epoch 92/100
# 300/300 [==============================] - 515s 2s/step - loss: -0.5404 - jaccard_coef: 0.5404 - val_loss: -0.5406 - val_jaccard_coef: 0.5406
#
# Epoch 00092: val_jaccard_coef did not improve from 0.54776
# Epoch 93/100
# 300/300 [==============================] - 512s 2s/step - loss: -0.5440 - jaccard_coef: 0.5440 - val_loss: -0.5307 - val_jaccard_coef: 0.5307
#
# Epoch 00093: val_jaccard_coef did not improve from 0.54776
# Epoch 94/100
# 300/300 [==============================] - 518s 2s/step - loss: -0.5353 - jaccard_coef: 0.5353 - val_loss: -0.5315 - val_jaccard_coef: 0.5315
#
# Epoch 00094: val_jaccard_coef did not improve from 0.54776
# Epoch 95/100
# 300/300 [==============================] - 507s 2s/step - loss: -0.5459 - jaccard_coef: 0.5459 - val_loss: -0.5350 - val_jaccard_coef: 0.5350
#
# Epoch 00095: val_jaccard_coef did not improve from 0.54776
# Epoch 96/100
# 300/300 [==============================] - 515s 2s/step - loss: -0.5335 - jaccard_coef: 0.5335 - val_loss: -0.5301 - val_jaccard_coef: 0.5301
#
# Epoch 00096: val_jaccard_coef did not improve from 0.54776
# Epoch 97/100
# 300/300 [==============================] - 523s 2s/step - loss: -0.5449 - jaccard_coef: 0.5449 - val_loss: -0.5378 - val_jaccard_coef: 0.5378
#
# Epoch 00097: val_jaccard_coef did not improve from 0.54776
# Epoch 98/100
# 300/300 [==============================] - 511s 2s/step - loss: -0.5443 - jaccard_coef: 0.5443 - val_loss: -0.5218 - val_jaccard_coef: 0.5218
#
# Epoch 00098: val_jaccard_coef did not improve from 0.54776
# Epoch 99/100
# 300/300 [==============================] - 509s 2s/step - loss: -0.5431 - jaccard_coef: 0.5431 - val_loss: -0.5424 - val_jaccard_coef: 0.5424
#
# Epoch 00099: val_jaccard_coef did not improve from 0.54776
# Epoch 100/100
# 300/300 [==============================] - 513s 2s/step - loss: -0.5360 - jaccard_coef: 0.5360 - val_loss: -0.5338 - val_jaccard_coef: 0.5338
#
# Epoch 00100: val_jaccard_coef did not improve from 0.54776

# %%
model.save(os.path.join(output_dir, 'transfer_learning_iter_100'.format(iterations)))

# %%
model.compile(optimizer=Adam(lr=1e-5), loss=jaccard_coef_loss, metrics=[jaccard_coef])
history2 = model.fit_generator(
    myGene,
    steps_per_epoch = 300, 
    epochs=200,
    initial_epoch = iterations,
    callbacks=[model_checkpoint],
    validation_data=myValGene,
    validation_steps=100)

model.save(os.path.join(output_dir, 'transfer_learning_iter_200'.format(iterations)))
# Out:
# Epoch 101/200
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-33-ff717d141bd9> in <module>
#       7     callbacks=[model_checkpoint],
#       8     validation_data=myValGene,
# ----> 9     validation_steps=100)
#      10
#      11 model.save(os.path.join(output_dir, 'transfer_learning_iter_200'.format(iterations)))
#
# ~\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     526             None, None,
#     527             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 528             c_api.TF_GetCode(self.status.status))
#     529     # Delete the underlying status object from memory otherwise it stays alive
#     530     # as there is a reference to status from this from the traceback due to
#
# ResourceExhaustedError: OOM when allocating tensor with shape[6,128,224,224] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node concatenate_10/concat}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[{{node metrics_2/jaccard_coef/Mean}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.

# %%
#Train all layers
for layer in model.layers:
    layer.trainable = True

    #Setup generator
UnetModel.batch_size = 2

history2 = model.fit_generator(
    myGene,
    steps_per_epoch = 780, 
    epochs=100,
    initial_epoch = iterations,
    callbacks=[model_checkpoint],
    validation_data=myValGene,
    validation_steps=260)

model.save(os.path.join(output_dir, 'transfer_learning_iter_100'.format(iterations)))
# Out:
# C:\Users\li_ni\Anaconda3\lib\site-packages\keras\engine\training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# Epoch 41/100
# 780/780 [==============================] - 1377s 2s/step - loss: -0.4312 - jaccard_coef: 0.4312 - val_loss: -0.2162 - val_jaccard_coef: 0.2162
#
# Epoch 00041: val_jaccard_coef did not improve from 0.22244
# Epoch 42/100
#  43/780 [>.............................] - ETA: 13:09 - loss: -0.4356 - jaccard_coef: 0.4356
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-3dea0e97753d> in <module>
#      13     callbacks=[model_checkpoint],
#      14     validation_data=myValGene,
# ---> 15     validation_steps=260)
#      16
#      17 model.save(os.path.join(output_dir, 'transfer_learning_iter_100'.format(iterations)))
#
# ~\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     179             batch_index = 0
#     180             while steps_done < steps_per_epoch:
# --> 181                 generator_output = next(output_generator)
#     182
#     183                 if not hasattr(generator_output, '__len__'):
#
# ~\Anaconda3\lib\site-packages\keras\utils\data_utils.py in get(self)
#     683         try:
#     684             while self.is_running():
# --> 685                 inputs = self.queue.get(block=True).get()
#     686                 self.queue.task_done()
#     687                 if inputs is not None:
#
# ~\Anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~\Anaconda3\lib\multiprocessing\pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
file_names = next(os.walk(test_data_dir))[2]

showPredictResult(file_names[4], model)
# Out:
# ISIC_0000029.jpg -- jaccard index: 0.7258504033088684

# %%
# Plot Training curve
plotTrainigGraph(history.history)
# Out:
# Training co-effiency    : 0.5462398161587609;
# Validation co-effiency : 0.5378165924968432

# %%
file = 'data/train/images/ISIC_0000000.jpg'
#grey_img = load_img(os.path.join(test_data_dir,file), target_size=(img_rows, img_cols), grayscale=False)
#mask_img = load_img(os.path.join(test_data_mask_dir,file.split('.')[0]+"_segmentation.png"), target_size=(224, 224), grayscale=True)
grey_img = load_img(file, target_size=(224, 224), grayscale=False)
mask_img = load_img('data/train/masks/ISIC_0000000_segmentation.png', target_size=(224, 224), grayscale=True)

img = img_to_array(grey_img)
img_mask = img_to_array(mask_img)

img, img_mask = normalizeData(img, img_mask)
img = np.reshape(img,(1,)+img.shape)

pred = model.predict([img])
sess = tf.Session()
score = sess.run(jaccard_coef(img_mask, pred))
print("{} -- jaccard index: {}".format(file,score))

result_img = array_to_img(pred[0] * 255 )
print(pred[0].shape)
f, ax = plt.subplots(1,2, figsize = (50,50))
ax[0].imshow(grey_img) 
ax[0].axis('off')
ax[0].set_title('image')
ax[1].imshow(result_img)
ax[1].axis('off')
ax[1].set_title('mask')
plt.show()
# Out:
# data/train/images/ISIC_0000000.jpg -- jaccard index: 0.7729514837265015
# (224, 224, 1)

# %%
coef = np.array(hist.history['jaccard_coef'])
val_coef = np.array(hist.history['val_jaccard_coef'])
print("Training co-effiency    : {};\nValidation co-effiency : {}".format(coef[coef==max(coef)][0], val_coef[np.argmax(coef)]))

# %%
# Generate Jaccard Index using test set
predictTestSet("unet/20190519/unet_lesion_20190519_059-0.80857.hdf5")

# %%
#This code combined 2 seperate training history together and plot the result
hist = {}
for i in history.history.keys():
    hist_concate = np.array([np.array(history.history[i]), np.array(history2.history[i])]).flatten() 
    hist[i] = hist_concate

plotTrainigGraph(hist)
